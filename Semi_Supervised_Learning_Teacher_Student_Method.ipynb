# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Subset
import torch.backends.cudnn as cudnn
import numpy as np
import random
from itertools import cycle
from copy import deepcopy

# %%
# Random parameters for the reproducibility

seed = 2025

cudnn.benchmark = False
cudnn.deterministic = True
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)

# %%
#Set the number of labeled, validated

labeled_num = 500
val_num = 1000

#Base Augmentation
transform = transforms.Compose([transforms.ToTensor()])

#Load MNIST dataset
dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

indices = np.arange(len(dataset))
np.random.shuffle(indices)

#The number of labeled samples
labeled_idx = indices[:labeled_num]

#The number of validation samples
val_idx = indices[labeled_num:labeled_num + val_num]

#The number of unlabeled samples
unlabeled_idx = indices[labeled_num + val_num:]

# Get labeled set by predefined indices
labeled_set = Subset(dataset, labeled_idx)

# Get validated set by predefined indices
val_set = Subset(dataset, val_idx)

#Set up loader for labeled set
labeled_loader = DataLoader(labeled_set, batch_size = 512, shuffle = True)

#Set up loader for validation set
val_loader = DataLoader(val_set, batch_size = 512, shuffle = False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 53.2MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.72MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.9MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.94MB/s]

# %%
# Weak-Strong augmentation
weak_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(28, padding = 4),
    transforms.ToTensor()
])

strong_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(28, padding = 4),
    transforms.RandomRotation(15),
    transforms.ToTensor()
])

#Load dataset with weak-strong augmentation
weak_transformed_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=weak_transform)
strong_transformed_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=strong_transform)

# %%
#Define a class for every pair of data from the weak and strong transformation

class PairedDataset(torch.utils.data.Dataset):
    def __init__(self, weak_dataset, strong_dataset):
        self.weak_dataset = weak_dataset
        self.strong_dataset = strong_dataset

    def __len__(self):
        return len(self.weak_dataset)

    def __getitem__(self, idx):
        weak_image, weak_label = self.weak_dataset[idx]
        strong_image, strong_label = self.strong_dataset[idx]
        return (weak_image, weak_label), (strong_image, strong_label)

# %%
# Get weak, strong augmented set by predefined indices
weak_unlabeled_set = Subset(weak_transformed_dataset, unlabeled_idx)
strong_unlabeled_set = Subset(strong_transformed_dataset, unlabeled_idx)

# Set up loader for unlabeled data
paired_unlabeled_set = PairedDataset(weak_unlabeled_set, strong_unlabeled_set)
unlabeled_loader = DataLoader(paired_unlabeled_set, batch_size = 512, shuffle = True)

# %%
# Create a model

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, kernel_size=2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, kernel_size=2)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Init model, optimizer, loss
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_student = CNN().to(device)
model_teacher = CNN().to(device)
model_teacher.load_state_dict(model_student.state_dict())

optimizer = optim.Adam(model_student.parameters(), lr= 0.001)
criterion = nn.CrossEntropyLoss()
thresh = 0.95
ema_decay = 0.99

#Variables for storing best model
iter_per_eval = 5
iter_num = 0
max_iter_num = 200

best_model = None
best_acc = 0

# %%
# Define the function for validation

def validation(model):
  # Move to evaluation model
  model.eval()
  correct = 0
  with torch.no_grad():
    for data, target in val_loader:
      # data, target = data.cuda(), target.cuda()
      data, target = data.to(device), target.to(device)
      output = model(data)
      pred = output.argmax(dim=1)
      correct += pred.eq(target).sum().item()

  acc_score = correct / len(val_set)
  print(f"Validation Accuracy: {acc_score}")
  model.train()
  return acc_score

# %%
# Define the function to update teacher model with EMA (Exponential Moving Average) formula

def update_teacher(model_student, model_teacher, ema_decay):
  with torch.no_grad():
    for t_param, s_param in zip(model_teacher.parameters(), model_student.parameters()):
      t_param.data.mul_(ema_decay).add_(s_param.data, alpha= 1 - ema_decay)

# %%
# Train model

model_student.train()
model_teacher.train()

for _ in range(100):
  for (labeled_data, labeled_target), ((weak_unlabeled_data, _), (strong_unlabeled_data, _)) in zip(cycle(labeled_loader), unlabeled_loader):
    labeled_data, labeled_target = labeled_data.to(device), labeled_target.to(device)
    weak_unlabeled_data, strong_unlabeled_data = weak_unlabeled_data.to(device), strong_unlabeled_data.to(device)

    #Supervised loss
    logist_x = model_student(labeled_data)
    loss_x = criterion(logist_x, labeled_target)

    #Unspervised consistency loss
    with torch.no_grad():
      teacher_preds = torch.softmax(model_teacher(weak_unlabeled_data), dim=1)
    student_preds = model_student(strong_unlabeled_data)

    max_probs, pseudo_labels = torch.max(teacher_preds, dim=1)
    mask = max_probs.ge(thresh).float()

    loss_u = (criterion(student_preds, pseudo_labels) * mask).mean()
    loss = loss_x + loss_u

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    update_teacher(model_student, model_teacher, ema_decay)

    iter_num += 1
    print(f"Iteration {iter_num}, Loss: {loss.item():.4f}")

    if iter_num % iter_per_eval == 0:
      acc_score = validation(model_student)
      if acc_score >= best_acc:
        best_acc = acc_score
        best_model = deepcopy(model_student)
        print(f"Save new best model at iter: {iter_num}")

    if iter_num == max_iter_num:
      break

  if iter_num == max_iter_num:
    break
# Out:
# Iteration 11, Loss: 1.1411
# Iteration 12, Loss: 1.0057
# Iteration 13, Loss: 0.8878
# Iteration 14, Loss: 0.7889
# Iteration 15, Loss: 0.7084
# Validation Accuracy: 0.76
# Save new best model at iter: 15
# Iteration 16, Loss: 0.6432
# Iteration 17, Loss: 0.5936
# Iteration 18, Loss: 0.5562
# Iteration 19, Loss: 0.5260
# Iteration 20, Loss: 0.4936
# Validation Accuracy: 0.804
# Save new best model at iter: 20
# Iteration 21, Loss: 0.4638
# Iteration 22, Loss: 0.4388
# Iteration 23, Loss: 0.4130
# Iteration 24, Loss: 0.3964
# Iteration 25, Loss: 0.3671
# Validation Accuracy: 0.824
# Save new best model at iter: 25
# Iteration 26, Loss: 0.3557
# Iteration 27, Loss: 0.3268
# Iteration 28, Loss: 0.3153
# Iteration 29, Loss: 0.2911
# Iteration 30, Loss: 0.2780
# Validation Accuracy: 0.841
# Save new best model at iter: 30
# Iteration 31, Loss: 0.2583
# Iteration 32, Loss: 0.2460
# Iteration 33, Loss: 0.2298
# Iteration 34, Loss: 0.2189
# Iteration 35, Loss: 0.2046
# Validation Accuracy: 0.851
# Save new best model at iter: 35
# Iteration 36, Loss: 0.1949
# Iteration 37, Loss: 0.1823
# Iteration 38, Loss: 0.1733
# Iteration 39, Loss: 0.1619
# Iteration 40, Loss: 0.1534
# Validation Accuracy: 0.864
# Save new best model at iter: 40
# Iteration 41, Loss: 0.1438
# Iteration 42, Loss: 0.1352
# Iteration 43, Loss: 0.1271
# Iteration 44, Loss: 0.1184
# Iteration 45, Loss: 0.1116
# Validation Accuracy: 0.863
# Iteration 46, Loss: 0.1035
# Iteration 47, Loss: 0.0971
# Iteration 48, Loss: 0.0901
# Iteration 49, Loss: 0.0837
# Iteration 50, Loss: 0.0777
# Validation Accuracy: 0.866
# Save new best model at iter: 50
# Iteration 51, Loss: 0.0717
# Iteration 52, Loss: 0.0666
# Iteration 53, Loss: 0.0615
# Iteration 54, Loss: 0.0567
# Iteration 55, Loss: 0.0525
# Validation Accuracy: 0.862
# Iteration 56, Loss: 0.0482
# Iteration 57, Loss: 0.0445
# Iteration 58, Loss: 0.0410
# Iteration 59, Loss: 0.0377
# Iteration 60, Loss: 0.0349
# Validation Accuracy: 0.861
# Iteration 61, Loss: 0.0322
# Iteration 62, Loss: 0.0298
# Iteration 63, Loss: 0.0277
# Iteration 64, Loss: 0.0256
# Iteration 65, Loss: 0.0238
# Validation Accuracy: 0.864
# Iteration 66, Loss: 0.0221
# Iteration 67, Loss: 0.0205
# Iteration 68, Loss: 0.0190
# Iteration 69, Loss: 0.0177
# Iteration 70, Loss: 0.0165
# Validation Accuracy: 0.866
# Save new best model at iter: 70
# Iteration 71, Loss: 0.0154
# Iteration 72, Loss: 0.0144
# Iteration 73, Loss: 0.0135
# Iteration 74, Loss: 0.0126
# Iteration 75, Loss: 0.0119
# Validation Accuracy: 0.867
# Save new best model at iter: 75
# Iteration 76, Loss: 0.0112
# Iteration 77, Loss: 0.0105
# Iteration 78, Loss: 0.0099
# Iteration 79, Loss: 0.0093
# Iteration 80, Loss: 0.0088
# Validation Accuracy: 0.87
# Save new best model at iter: 80
# Iteration 81, Loss: 0.0084
# Iteration 82, Loss: 0.0079
# Iteration 83, Loss: 0.0075
# Iteration 84, Loss: 0.0071
# Iteration 85, Loss: 0.0068
# Validation Accuracy: 0.871
# Save new best model at iter: 85
# Iteration 86, Loss: 0.0481
# Iteration 87, Loss: 0.0063
# Iteration 88, Loss: 0.0264
# Iteration 89, Loss: 0.0059
# Iteration 90, Loss: 0.0277
# Validation Accuracy: 0.872
# Save new best model at iter: 90
# Iteration 91, Loss: 0.0053
# Iteration 92, Loss: 0.0688
# Iteration 93, Loss: 0.0944
# Iteration 94, Loss: 0.0050
# Iteration 95, Loss: 0.1362
# Validation Accuracy: 0.875
# Save new best model at iter: 95
# Iteration 96, Loss: 0.1545
# Iteration 97, Loss: 0.1328
# Iteration 98, Loss: 0.0904
# Iteration 99, Loss: 0.1226
# Iteration 100, Loss: 0.1769
# Validation Accuracy: 0.873
# Iteration 101, Loss: 0.1496
# Iteration 102, Loss: 0.2217
# Iteration 103, Loss: 0.0621
# Iteration 104, Loss: 0.1027
# Iteration 105, Loss: 0.1298
# Validation Accuracy: 0.874
# Iteration 106, Loss: 0.2093
# Iteration 107, Loss: 0.2265
# Iteration 108, Loss: 0.2260
# Iteration 109, Loss: 0.2354
# Iteration 110, Loss: 0.2058
# Validation Accuracy: 0.885
# Save new best model at iter: 110
# Iteration 111, Loss: 0.2096
# Iteration 112, Loss: 0.3506
# Iteration 113, Loss: 0.2913
# Iteration 114, Loss: 0.1978
# Iteration 115, Loss: 0.2472
# Validation Accuracy: 0.893
# Save new best model at iter: 115
# Iteration 116, Loss: 0.2092
# Iteration 117, Loss: 0.1586
# Iteration 118, Loss: 0.2178
# Iteration 119, Loss: 0.1860
# Iteration 120, Loss: 0.2149
# Validation Accuracy: 0.903
# Save new best model at iter: 120
# Iteration 121, Loss: 0.1821
# Iteration 122, Loss: 0.2482
# Iteration 123, Loss: 0.1880
# Iteration 124, Loss: 0.2104
# Iteration 125, Loss: 0.2252
# Validation Accuracy: 0.911
# Save new best model at iter: 125
# Iteration 126, Loss: 0.2025
# Iteration 127, Loss: 0.1907
# Iteration 128, Loss: 0.2055
# Iteration 129, Loss: 0.2299
# Iteration 130, Loss: 0.2488
# Validation Accuracy: 0.916
# Save new best model at iter: 130
# Iteration 131, Loss: 0.2112
# Iteration 132, Loss: 0.1727
# Iteration 133, Loss: 0.2184
# Iteration 134, Loss: 0.2205
# Iteration 135, Loss: 0.2192
# Validation Accuracy: 0.914
# Iteration 136, Loss: 0.1693
# Iteration 137, Loss: 0.2748
# Iteration 138, Loss: 0.2136
# Iteration 139, Loss: 0.1789
# Iteration 140, Loss: 0.1829
# Validation Accuracy: 0.917
# Save new best model at iter: 140
# Iteration 141, Loss: 0.2159
# Iteration 142, Loss: 0.1770
# Iteration 143, Loss: 0.2586
# Iteration 144, Loss: 0.2172
# Iteration 145, Loss: 0.2113
# Validation Accuracy: 0.925
# Save new best model at iter: 145
# Iteration 146, Loss: 0.2554
# Iteration 147, Loss: 0.2225
# Iteration 148, Loss: 0.1550
# Iteration 149, Loss: 0.2024
# Iteration 150, Loss: 0.1951
# Validation Accuracy: 0.923
# Iteration 151, Loss: 0.2283
# Iteration 152, Loss: 0.1754
# Iteration 153, Loss: 0.1836
# Iteration 154, Loss: 0.2104
# Iteration 155, Loss: 0.1962
# Validation Accuracy: 0.926
# Save new best model at iter: 155
# Iteration 156, Loss: 0.1886
# Iteration 157, Loss: 0.1838
# Iteration 158, Loss: 0.2066
# Iteration 159, Loss: 0.2445
# Iteration 160, Loss: 0.1483
# Validation Accuracy: 0.928
# Save new best model at iter: 160
# Iteration 161, Loss: 0.1604
# Iteration 162, Loss: 0.2292
# Iteration 163, Loss: 0.2251
# Iteration 164, Loss: 0.1892
# Iteration 165, Loss: 0.1578
# Validation Accuracy: 0.925
# Iteration 166, Loss: 0.1740
# Iteration 167, Loss: 0.2787
# Iteration 168, Loss: 0.1382
# Iteration 169, Loss: 0.1866
# Iteration 170, Loss: 0.1915
# Validation Accuracy: 0.929
# Save new best model at iter: 170
# Iteration 171, Loss: 0.1481
# Iteration 172, Loss: 0.2009
# Iteration 173, Loss: 0.1664
# Iteration 174, Loss: 0.1752
# Iteration 175, Loss: 0.1985
# Validation Accuracy: 0.928
# Iteration 176, Loss: 0.2157
# Iteration 177, Loss: 0.1870
# Iteration 178, Loss: 0.2071
# Iteration 179, Loss: 0.2021
# Iteration 180, Loss: 0.2072
# Validation Accuracy: 0.93
# Save new best model at iter: 180
# Iteration 181, Loss: 0.1994
# Iteration 182, Loss: 0.1793
# Iteration 183, Loss: 0.1780
# Iteration 184, Loss: 0.1740
# Iteration 185, Loss: 0.1432
# Validation Accuracy: 0.94
# Save new best model at iter: 185
# Iteration 186, Loss: 0.1741
# Iteration 187, Loss: 0.1716
# Iteration 188, Loss: 0.1820
# Iteration 189, Loss: 0.1628
# Iteration 190, Loss: 0.1754
# Validation Accuracy: 0.936
# Iteration 191, Loss: 0.1685
# Iteration 192, Loss: 0.2235
# Iteration 193, Loss: 0.1963
# Iteration 194, Loss: 0.2393
# Iteration 195, Loss: 0.1555
# Validation Accuracy: 0.935
# Iteration 196, Loss: 0.1485
# Iteration 197, Loss: 0.2119
# Iteration 198, Loss: 0.1694
# Iteration 199, Loss: 0.1895
# Iteration 200, Loss: 0.1807
# Validation Accuracy: 0.936

# %%
# Evaluate model

def test(model):
  model.eval()
  test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
  test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False)
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      data, target = data.to(device), target.to(device)
      output = model(data)
      pred = output.argmax(dim=1)
      correct += pred.eq(target).sum().item()
  print(f"Test Accuracy: {correct/len(test_dataset):.4f}")

test(best_model)
# Out:
# Test Accuracy: 0.9440
